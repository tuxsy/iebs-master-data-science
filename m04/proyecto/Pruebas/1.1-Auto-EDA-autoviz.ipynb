# %%
# Descargar el fichero
! [ -f ASI_casoPractico.csv ] || wget https://raw.githubusercontent.com/tuxsy/iebs-master-data-science/main/m04/c2/sprint/ASI_casoPractico.csv

# %%
# Instalar Autoviz
! pip install autoviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Importar el dataset en autoviz
from autoviz.AutoViz_Class import AutoViz_Class#Instantiate the AutoViz class
AV = AutoViz_Class()

# %%
import pandas as pd

df = pd.read_csv("ASI_casoPractico.csv", sep=";")

dftc = AV.AutoViz(
    filename='', sep ='' , depVar ='Target', dfte = df, header = 0,
verbose = 1, lowess = False, chart_format ='png', max_rows_analyzed = 15000, max_cols_analyzed = 30)
# Out:
# Shape of your Data Set loaded: (2126, 26)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# Data cleaning improvement suggestions. Complete them before proceeding to ML modeling.
# <style type="text/css">
# #T_34296_row0_col0, #T_34296_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# ...
